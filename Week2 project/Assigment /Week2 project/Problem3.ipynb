# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.tsa.arima_process import ArmaProcess
#plt.rcParams['figure.figsize'] = (10, 5)
# Plot 1: AR parameter = 0.8
ar = np.array([1, -0.6])
ma = np.array([1])
AR_object = ArmaProcess(ar, ma)
simulated_data_1 = AR_object.generate_sample(nsample=1000)
plt.plot(simulated_data_1);


# Plot 1: AR parameter = 0.8
#ACF
plot_acf(simulated_data_1, alpha=1, lags=20);
#PACF
#Plot 1: AR parameter = 0.8
plot_pacf(simulated_data_1, lags=20);

#Plot 2: AR parameter = 0.64

ar2 = np.array([1, -0.6,-0.3])
ma2 = np.array([1])
AR_object2 = ArmaProcess(ar2, ma2)
simulated_data_2 = AR_object2.generate_sample(nsample=1000)
#plt.plot(simulated_data_2);

# Plot 2: AR parameter = 0.6
#ACF
#plot_acf(simulated_data_2, alpha=1, lags=20);
#PACF
#Plot 2: AR parameter = 0.6
#plot_pacf(simulated_data_2, lags=20);

ar3 = np.array([1, -0.6,-0.3,-0.1])
ma3 = np.array([1])
AR_object3 = ArmaProcess(ar3, ma3)
simulated_data_3 = AR_object3.generate_sample(nsample=1000)
#plt.plot(simulated_data_3);

# Plot 2: AR parameter = 0.6
#ACF
#plot_acf(simulated_data_3, alpha=1, lags=20);
#PACF
#Plot 2: AR parameter = 0.6
#plot_pacf(simulated_data_3, lags=20);
# Out:
# /Users/fend/opt/anaconda3/lib/python3.9/site-packages/statsmodels/graphics/tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
ar4 = np.array([1])
ma4 = np.array([1, -0.6])
MA_object4 = ArmaProcess(ar4, ma4)
simulated_data_4 = MA_object4.generate_sample(nsample=1000)
#plt.plot(simulated_data_4);
#plot_acf(simulated_data_4, lags=20);
#plot_pacf(simulated_data_4, lags=20);

ar5 = np.array([1])
ma5 = np.array([1, -0.6,-0.3])
MA_object5 = ArmaProcess(ar5, ma5)
simulated_data_5 = MA_object5.generate_sample(nsample=1000)
#plt.plot(simulated_data_5);
#plot_acf(simulated_data_5, lags=20);
#plot_pacf(simulated_data_5, lags=20);

ar6 = np.array([1])
ma6 = np.array([1, -0.6,-0.3,-0.1])
MA_object6 = ArmaProcess(ar6, ma6)
simulated_data_6 = MA_object6.generate_sample(nsample=1000)
plt.plot(simulated_data_6);
plot_acf(simulated_data_6, lags=20);
plot_pacf(simulated_data_6, lags=20);
# Out:
# /Users/fend/opt/anaconda3/lib/python3.9/site-packages/statsmodels/graphics/tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(
